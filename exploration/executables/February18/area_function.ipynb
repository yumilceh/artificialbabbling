# %% [markdown]
# # DIVA

# %%
# %matplotlib inline
import os
import itertools
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
from exploration.systems.diva2018 import Diva2018

# %%
system = Diva2018()
system.set_action(system.min_motor_values_init*0.2)
system.execute_action()

# %%
matplotlib.rcParams['figure.figsize'] = (12.0, 6.)
matplotlib.rcParams.update({'font.size': 20, 'font.weight': 'bold'})

fig, ax = plt.subplots(1,2)

system.plot_vt_shape(axes=ax[0])
system.plot_af_shape(axes=ax[1])
# ax1[0,0].set_title('Mean competence')
# data.plot_time_series('competence',0,moving_average=1000,axes=ax1[0,0])
# plt.xlabel('Experiment[$k$]')
# plt.ylabel('Competence')
# plt.tight_layout()

# %%
fig.savefig('/home/yumilceh/Dropbox/Aplicaciones/ShareLaTeX/PhD Thesis/area_funtion.eps',\
              format='eps', bbox_inches='tight')
