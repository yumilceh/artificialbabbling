# %%
# %matplotlib inline
import os
import itertools
import matplotlib
import numpy as np
import pylab as plt
import matplotlib

# %%
from exploration.data.data import load_sim_h5_v2 as load_sim_h5
from exploration.data.PlotTools import *

# %%
data, foo = load_sim_h5('../../systems/datasets/german_dataset_somato.h5')
sensor_data = data.sensor.data.as_matrix()[-17:,:]

# %%
matplotlib.rcParams.update({'font.size': 18, 'font.weight': 'bold'})
matplotlib.rcParams['figure.figsize'] = (8.8, 8.)
fig, ax = plt.subplots(1,1)
plt.plot(sensor_data[:,3],sensor_data[:,4],'ob',ms=6.)
#diva_output_scale = [100.0, 500.0, 1500.0, 3000.0]
plt.xlabel(r'$F_1$ ($\times 500Hz$)', weight='bold')
plt.ylabel(r'$F_2$ ($\times 1500Hz$)', weight='bold')
plt.xlim([-0.02,1.6])
plt.ylim([-0.02,1.6])
plt.grid(True)

text_vowels = {'/a:/' : [1.3215 , 0.7958] , '/a/' : [1.2910, 0.862],  \
    '/e:/' : [0.5674 , 1.4658] , '/E:/' : [1.0520 , 1.2787],\
    '/i:/' : [0.4300 , 1.4527] , '/y:/' : [0.6206, 1.0972], \
    '/o:/' : [0.4968 , 0.4701] , '/O/' : [1.1117 , 0.6238], \
    '/u:/' : [0.6820 , 0.4493] , '/U/' : [0.8100 , 0.6340], \
    '/2:/' : [0.6691 , 0.8740] , '/@/' : [0.8700 , 1.076], \
    '/I/' : [0.812 , 1.2427] ,   '/E/' : [1.0640 , 1.22],  \
    '/Y/' : [0.792 , 0.8680] ,   '/9/' : [1.002  , 0.8893], \
    '/6/' : [1.2316, 0.9175] }
# for key in text_vowels.keys():
#     plt.text(text_vowels[key][0]+.02, text_vowels[key][1], key, fontsize=15)

# %%
fig.savefig('/home/yumilceh/Dropbox/Aplicaciones/ShareLaTeX/PhD_Thesis/chapters/chapter5/images/german_units.eps',\
              format='eps', bbox_inches='tight')
# fig.savefig('c:/Users/yumilceh/Dropbox/Aplicaciones/ShareLaTeX/PhD_Thesis/chapters/chapter6/images/german_units.eps',\
#               format='eps', bbox_inches='tight')
