# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

# %%
from SensorimotorExploration.Systems.Parabola_v2 import ParabolicRegion as System
from SensorimotorExploration.Systems.Parabola_v2 import Instructor

# %%
system = System()
instructor = Instructor()

# %%
matplotlib.rcParams['figure.figsize'] = (9.0, 6.0)
matplotlib.rcParams.update({'font.size': 18})

title_font = {'fontname':'Arial', 'size':'16', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} # Bottom vertical alignment for more space
axis_font = {'size':'30'}

fig, ax = plt.subplots(1,1) 
instructor.data.plot_2D('sensor',1,'sensor',0,color='ob',axes=ax)
plt.hold(True)
system.drawSystem(ax, flip=True)
ax.set_ylim([0,6])
ax.set_xlim([0,9])
plt.xlabel('$s_2$',**axis_font)
plt.ylabel('$s_1$',**axis_font)
plt.legend(['Sensor units','Constraints'],loc='upper left',fontsize=15)

# %%
fig.savefig('/home/yumilceh/Dropbox/Aplicaciones/ShareLaTeX/IEEE_TCDS_Special_Issue/images/system_parabola.eps',format='eps', dpi=1000)

# %%
# Out:
# algorithm_2015.py                   __init__.py
# algorithm_2017a_pool_GREC.py        manual_execution.py
# algorithm_2017a_pool.py             model_configurations.py
# algorithm_2017a.py                  model_configurations.pyc
# algorithm_2017a_unpack_pool_old.py  plot_results.py
# algorithm_2017a_unpack_pool.py      plotSystem.ipynb
# experiment_1/                       system_parabola.eps
# generate_instructor.py              trash/
# generate_videos_from_instructor.py  unpack_pool_alg2017.ipynb
