# %%
# %matplotlib inline
import os
import itertools
import matplotlib
import numpy as np
import pylab as plt
import matplotlib

# %%
from exploration.data.data import load_sim_h5_v2 as load_sim_h5
from exploration.data.PlotTools import *

# %%
data, foo = load_sim_h5('../../systems/datasets/german_dataset_somato.h5')
sensor_data = data.sensor.data.as_matrix()

# %%
matplotlib.rcParams.update({'font.size': 18, 'font.weight': 'bold'})
matplotlib.rcParams['figure.figsize'] = (8.8, 8.)
fig, ax = plt.subplots(1,1)
plt.plot(sensor_data[:,0],sensor_data[:,1],'ob',ms=6.)
#diva_output_scale = [100.0, 500.0, 1500.0, 3000.0]
plt.xlabel(r'$F_1$ ($\times 500Hz$)')
plt.ylabel(r'$F_2$ ($\times 1500Hz$)')
plt.xlim([-0.02,1.6])
plt.ylim([-0.02,1.6])
plt.grid(True)

# %%
# fig.savefig('/home/yumilceh/Dropbox/Aplicaciones/ShareLaTeX/PhD Thesis/german_units.eps',\
#               format='eps', bbox_inches='tight')
fig.savefig('c:/Users/yumilceh/Dropbox/Aplicaciones/ShareLaTeX/PhD_Thesis/chapters/chapter5/images/german_units.eps',\
              format='eps', bbox_inches='tight')
